# %% [markdown]
# # Automação de Sistemas e Processos com Python
#
# ### Desafio:
#
# Todos os dias, o nosso sistema atualiza as vendas do dia anterior.
# O seu trabalho diário, como analista, é enviar um e-mail para a diretoria, assim que começar a trabalhar, com o faturamento e a quantidade de produtos vendidos no dia anterior
#
# E-mail da diretoria: seugmail+diretoria@gmail.com<br>
# Local onde o sistema disponibiliza as vendas do dia anterior: https://drive.google.com/drive/folders/1rB8UzwHD4geiAW0oW_FgPHzLNXrWOtcf?usp=sharing
#
# Para resolver isso, vamos usar o pyautogui, uma biblioteca de automação de comandos do mouse e do teclado
#
# https://pyautogui.readthedocs.io/en/latest/quickstart.html

# %%
import pyautogui
import time
import pyperclip
import pandas as pd

# %%
pyautogui.PAUSE = 1

pyautogui.alert("Processo de automação, aperte OK e não mexa em nada")

#Passo a passo de como realizaremos nossa automação:

#Passo 1 - Entrar no sistema da empresa (entrar no link do google drive)https://drive.google.com/drive/folders/1rB8UzwHD4geiAW0oW_FgPHzLNXrWOtcf?usp=sharing

#Passo 2 - Navegar até o local onde está nossa base da dados (Entrar na pasta "Exportar")
#Passo 3 - Baixar a planilha de vendas
#Passo 4 - Analisar a planilha (Calcular o faturamento e quantidade de produtos vendidos da base)
#Passo 5 - Enviar email para diretoria com a quantidade e o faturamento que calculamos

#Passo 1: Entrar no sistema da empresa
pyautogui.press('win')
pyautogui.write('Chrome')
pyautogui.press('enter')
url = 'https://drive.google.com/drive/folders/1rB8UzwHD4geiAW0oW_FgPHzLNXrWOtcf?usp=sharing'
pyperclip.copy(url)
pyautogui.hotkey('ctrl', 'v')
pyautogui.press('enter')

# %%
#Passo 2: Navegar até o local onde está a base de dados
time.sleep(10) #Computador espera por 10s
#pyautogui.position(403, 259)



time.sleep(5)
pyautogui.click(403, 259, clicks=2)
pyautogui.click(377, 355)
pyautogui.click(1160, 159)
#Passo 3: Baixar a planilha de dados
pyautogui.click(986, 564)

#Passo 4: Analisar a planilha 
df = pd.read_excel("C://Users/alonp/Downloads/Vendas - Dez.xlsx")

faturamento = df["Valor Final"].sum()
quantidade = df["Quantidade"].sum()
print(faturamento)
print(quantidade)

#Passo 5: Enviar o email
#Abrir o gmail
pyautogui.press('win')
pyautogui.write('Chrome')
pyautogui.press('enter')
#Entrar no gmail
link = 'https://mail.google.com/'
pyperclip.copy(link)
pyautogui.hotkey('ctrl', 'v')
pyautogui.press('enter')
time.sleep(10)
#Clicar no botao escrever
pyautogui.click(112, 181)

#digitar para quem vamos enviar
email = 'gabrielbarrosnog@gmail.com'
pyautogui.write(email)
pyautogui.press('tab')
pyautogui.press('tab')
#digitar o assunto
assunto = "Relatório de vendas"
pyperclip.copy(assunto)
pyautogui.hotkey('ctrl', 'v')

pyautogui.press('tab')
#digitar o corpo do email
"""
#texto_email = f"""
"""
Prezados Bom dia

O faturamento do dia de ontem foi de: R$ {faturamento:,.2f}
A quantidade de produtos vendidos foi de: {quantidade:,}

Atenciosamente
Gabriel Barros Nogueira
RA 123456
"""
"""
pyperclip.copy(texto_email)
pyautogui.hotkey('ctrl', 'v')
#clicar em enviar
pyautogui.hotkey('ctrl', 'enter')
"""
